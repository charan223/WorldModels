# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# %matplotlib inline

# %%
with open('evo_vae_28_pop_size_800_length_4_avg_rollout.pkl', 'rb') as f:
    info_loaded1 = pickle.load(f)

# %%
generation = info_loaded1[2][3]
print (info_loaded1[2][3]) #number generations stored
# Out:
# 41

# %%
data = info_loaded1[2][2]

# %%
maxes = np.array(data).T[0]
avgs = np.array(data).T[1]
mins = np.array(data).T[2]

# %%
t = np.arange(0., generation ,1)

# %%
print(maxes ,avgs, mins)
# Out:
# [   4.20772464    2.23967352   -0.63133      -4.30030334  -12.36427784
#   -20.52826118  -16.32749677  -22.96680716  -17.59108709  -17.10074174
#   -35.71289873  -38.5635909   -53.11555819  -93.55462866  -70.05898177
#   -76.99642407 -109.07534779 -155.04946891 -195.50169934 -159.9075854
#  -176.67679597 -239.79152864 -262.35337197 -245.29815401 -269.33002608
#  -192.66231496 -214.75880131 -236.34001215 -285.18102023 -276.28663393
#  -244.01007169 -308.53646592 -291.24892217 -328.78601114 -295.0291512
#  -285.21548123 -295.00250287 -356.44872661 -367.85845141 -346.34404955
#  -292.11605173] [ 1.37187561e+01  1.13826690e+01  9.23577487e+00  6.92541258e+00
#   6.51778511e+00  5.63142590e+00  1.55850172e+00  9.69506499e-03
#  -2.93495282e+00 -1.60196660e+00 -2.59070479e+00 -7.18472896e+00
#  -1.48712784e+01 -1.85059888e+01 -2.71110693e+01 -3.32012934e+01
#  -3.90466864e+01 -5.33215878e+01 -7.00299529e+01 -7.31993797e+01
#  -7.60065895e+01 -1.01002887e+02 -9.78561079e+01 -9.89224644e+01
# ...

# %%
#plt.clear()
plt.plot(t, -maxes, 'r--', t,-avgs, 'b--', t, -mins, 'g--')
#plt.plot(t, -maxes, 'ro', t,-avgs, 'bo', t, -mins, 'go')

# %%
import cma

# %%
info_loaded1[0].plot()

# %%
info_loaded1[0].result
# Out:
# CMAEvolutionStrategyResult(xbest=array([ 0.13315774, -0.24015602,  0.10632894,  0.28301554,  0.3606825 ,
#        -0.26892978,  0.35709892, -0.12076625,  0.10093675, -0.6686399 ,
#         0.02885091, -0.23905812,  0.18106755,  0.2085777 , -0.16975333,
#         0.35428322,  0.13911775,  0.12379711, -0.12357699,  0.14424815,
#        -0.311586  , -0.05757572, -0.16580884,  0.00723153,  0.18335636,
#        -0.08882685, -0.0904301 ,  0.10306455,  0.29752013, -0.06654697,
#         0.41646436, -0.16357788,  0.12219094,  0.02729265, -0.22818496,
#         0.10691386,  0.11399322, -0.32878551,  0.08217642, -0.08975662,
#         0.15056373,  0.15193969,  0.08933583, -0.33197114, -0.07276768,
#         0.06492258,  0.25406015,  0.21717012, -0.26056983, -0.0152447 ,
#         0.08345956, -0.21841509, -0.10218761, -0.19379883,  0.15508424,
#        -0.19788443,  0.06557584,  0.06431824, -0.15815852, -0.2015109 ,
#         0.26225155, -0.08586173,  0.04418098, -0.23886678,  0.0809283 ,
# ...
